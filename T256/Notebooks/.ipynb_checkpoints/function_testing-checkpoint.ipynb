# %%
sys.path.append(os.path.abspath(".."))


project_root = Path("..").resolve()
data_dir = project_root / "Data"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 sys.path.append(os.path.abspath(".."))
#       4 project_root = Path("..").resolve()
#       5 data_dir = project_root / "Data"
#
# NameError: name 'sys' is not defined

# %%
import numpy as np
import pandas as pd
import torch

from pathlib import Path
import sys, os

# from src.dataset import T5000Dataset, create_dataloader
# from src.pbc_config import BOX, wrap, min_image

import torch
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 8
#       5 from pathlib import Path
#       6 import sys, os
# ----> 8 from src.dataset import T5000Dataset, create_dataloader
#       9 from src.pbc_config import BOX, wrap, min_image
#
# ModuleNotFoundError: No module named 'src'

# %%
torch.manual_seed(42)
torch.save(torch.rand(256,3), '../Data/fixed_x0_256.pt')

# %%
cosmologies_dir = data_dir
cosmologies_info_dir = data_dir

train_dataset = T5000Dataset(cosmologies_dir, cosmologies_info_dir, split='train')
test_dataset = T5000Dataset(cosmologies_dir, cosmologies_info_dir, split='test')

print(len(test_dataset))

# %%
train_loader, test_loader, sampler = create_dataloader(cosmologies_dir, 
                                                       cosmologies_info_dir, 
                                                       batch_size=16,
                                                       rotations=True,
                                                       translations=True,
                                                       distributed=True
                                                       )
graph = next(iter(train_loader))
graph
